# %%
import pandas as pd
import openpyxl as op

# %%
matches_df = pd.read_excel('datasets/matches.xlsx', sheet_name='Matches')
matches_df.head()
# match_id is an identification number for a unique match, as well as a primary key in my SQL database from which the data came from at the first place
# match_date, of course, is a date of a given match
# match is a specific matchup of two teams
# predicted_winner contains the name of a team that I'm betting on to win the game
# match_value contains a float number of betting odds for a specific bet
# match_got_it says if a bet was successful, containing boolean values of 'YES' or 'NO'
# over_under is another kind of bet, where I'm predicting how many points will be scored in the given match
# over_under_value contains a float number of betting odds for over_under bet
# over_under_got_it also says if the bet was successful with the same boolean values of 'YES' or 'NO'
# Out:
#    MATCH_ID MATCH_DATE                                        MATCH  \
# 0         1 2022-12-10               MIAMI HEAT - SAN ANTONIO SPURS
# 1         2 2022-12-10    WASHINGTON WIZARDS - LOS ANGELES CLIPPERS
# 2         3 2022-12-10               INDIANA PACERS - BROOKLYN NETS
# 3         4 2022-12-10  CLEVELAND CAVALIERS - OKLAHOMA CITY THUNDER
# 4         5 2022-12-10             CHICAGO BULLS - DALLAS MAVERICKS
#
#        PREDICTED_WINNER  MATCH_VALUE MATCH_GOT_IT  OVER_UNDER  \
# 0            MIAMI HEAT         1.11           NO      -224.5
# 1  LOS ANGELES CLIPPERS         1.53          YES       220.5
# 2        INDIANA PACERS         1.32           NO       230.5
# 3   CLEVELAND CAVALIERS         1.36          YES       223.5
# 4      DALLAS MAVERICKS         2.00           NO      -226.5
#
#    OVER_UNDER_VALUE OVER_UNDER_GOT_IT
# 0              1.84                NO
# 1              1.94               YES
# 2              2.04               YES
# ...
